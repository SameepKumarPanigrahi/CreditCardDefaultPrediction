# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# f:\VSCode\CreditCardDefaultPrediction\env\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
path = r"F:\VSCode\CreditCardDefaultPrediction\creditcard\artifact\data_ingestion\2022-07-18-17-04-36\raw_data\UCI_Credit_Card.csv"

# %%
df = pd.read_csv(path)
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
path = r'F:\VSCode\CreditCardDefaultPrediction\creditcard\artifact\data_transformation\2022-07-23-17-27-49\transformed_data\train\UCI_Credit_Card.npz'

# %%
from creditcard.util.util import *
import pandas as pd

# %%
data = load_numpy_array_data(file_path=path)

# %%
pd.DataFrame(data)
# Out:
#              0        1         2         3         4         5         6   \
# 0      0.240123 -0.80844  0.184523  0.856739 -0.264558  1.793311  1.780193
# 1      0.163525 -0.80844 -1.077532  0.856739 -0.155804  0.902944 -0.722324
# 2     -2.099236  1.23695  0.184523 -1.059367  1.584260  0.902944  1.780193
# 3      0.638185 -0.80844 -1.077532  0.856739 -0.699574  0.012576  0.111849
# 4      1.106768 -0.80844 -1.077532  0.856739 -0.373312  0.902944 -1.556496
# ...         ...      ...       ...       ...       ...       ...       ...
# 23995 -0.288444 -0.80844  0.184523  0.856739 -0.482066  0.012576  0.111849
# 23996 -0.091299 -0.80844  0.184523  0.856739 -1.243344  0.012576  0.111849
# 23997 -0.091299 -0.80844 -1.077532  0.856739 -1.243344  0.012576  0.111849
# 23998  1.325012  1.23695 -1.077532 -1.059367  2.345538  0.902944 -1.556496
# 23999  1.060073  1.23695 -1.077532 -1.059367 -0.047050 -0.877791 -0.722324
#
# ...
